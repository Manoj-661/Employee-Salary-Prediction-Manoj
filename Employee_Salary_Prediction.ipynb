# %% [markdown]
# # Importing The Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importing The Dataset

# %%
dataset = pd.read_csv('adult 3.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values.reshape(-1, 1)

# %%
dataset
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
print(x)
# Out:
# [[25 'Private' 226802 ... 0 40 'United-States']
#  [38 'Private' 89814 ... 0 50 'United-States']
#  [28 'Local-gov' 336951 ... 0 40 'United-States']
#  ...
#  [58 'Private' 151910 ... 0 40 'United-States']
#  [22 'Private' 201490 ... 0 20 'United-States']
#  [52 'Self-emp-inc' 287927 ... 0 40 'United-States']]

# %%
print(y)
# Out:
# [['<=50K']
#  ['<=50K']
#  ['>50K']
#  ...
#  ['<=50K']
#  ['<=50K']
#  ['>50K']]

# %%
dataset.shape
# Out:
# (48842, 15)

# %% [markdown]
# # Finding Null Values

# %%
dataset.isna()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
dataset.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
print(dataset.age.value_counts())
# Out:
# age
# 36    1348
# 35    1337
# 33    1335
# 23    1329
# 31    1325
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: count, Length: 74, dtype: int64

# %%
print(dataset.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
print(dataset.fnlwgt.value_counts())
# Out:
# fnlwgt
# 203488    21
# 190290    19
# 120277    19
# 125892    18
# 126569    18
#           ..
# 436163     1
# 320084     1
# 125976     1
# 211349     1
# 120478     1
# Name: count, Length: 28523, dtype: int64

# %%
print(dataset.gender.value_counts())
# Out:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
print(dataset['marital-status'].value_counts())
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
print(dataset['education'].value_counts())
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
print(dataset['workclass'].value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
dataset.occupation.replace({'?':'Others' },inplace = True)
# Out:
# /tmp/ipython-input-113-1604406918.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset.occupation.replace({'?':'Others' },inplace = True)

# %%
print(dataset.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Others               2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
dataset.workclass.replace({'?':'NotListed'},inplace = True)
# Out:
# /tmp/ipython-input-115-796324901.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset.workclass.replace({'?':'NotListed'},inplace = True)

# %%
print(dataset['workclass'].value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# NotListed            2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
dataset['native-country'].replace({'?':'Unknown'},inplace = True)
# Out:
# /tmp/ipython-input-117-2092033047.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['native-country'].replace({'?':'Unknown'},inplace = True)

# %%
print(dataset['native-country'].value_counts())
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# Unknown                         857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# ...

# %% [markdown]
# # Removing The Unnecessary Values From The Each Column

# %%
dataset = dataset[dataset['workclass']!='Without-pay']
dataset = dataset[dataset['workclass']!='Never-worked']

# %%
print(dataset['workclass'].value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# NotListed            2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Name: count, dtype: int64

# %%
dataset.shape
# Out:
# (48811, 15)

# %%
dataset = dataset[dataset['education']!='Preschool']
dataset = dataset[dataset['education']!='1st-4th']
dataset = dataset[dataset['education']!='5th-6th']

# %%
print(dataset['education'].value_counts())
# Out:
# education
# HS-grad         15768
# Some-college    10873
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1809
# Assoc-acdm       1599
# 10th             1387
# 7th-8th           952
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# Name: count, dtype: int64

# %% [markdown]
# # Redundancy

# %%
dataset
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18     NotListed  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
dataset.drop(columns = ['relationship'], inplace = True)

# %%
dataset
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18     NotListed  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   race  gender  capital-gain  \
# 0           Never-married  Machine-op-inspct  Black    Male             0
# ...

# %% [markdown]
# # Removing Outlier

# %%
import matplotlib.pyplot as plt
plt.boxplot(dataset['age'])
plt.show()

# %%
import seaborn as sns
numerical_cols = ['age', 'fnlwgt', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(y=dataset[col], color='skyblue')
    plt.title(f'Before: {col}')
plt.tight_layout()
plt.show()

# %%
dataset_cleaned = dataset.copy()
for col in numerical_cols:
    Q1 = dataset_cleaned[col].quantile(0.25)
    Q3 = dataset_cleaned[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    dataset_cleaned = dataset_cleaned[(dataset_cleaned[col] >= lower_bound) & (dataset_cleaned[col] <= upper_bound)]

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(y=dataset_cleaned[col], color='lightgreen')
    plt.title(f'After: {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
dataset['workclass'] = encoder.fit_transform(dataset['workclass'])
dataset['marital-status'] = encoder.fit_transform(dataset['marital-status'])
dataset['occupation'] = encoder.fit_transform(dataset['occupation'])
dataset['race'] = encoder.fit_transform(dataset['race'])
dataset['gender'] = encoder.fit_transform(dataset['gender'])
dataset['native-country'] = encoder.fit_transform(dataset['native-country'])

# %%
dataset
# Out:
#        age  workclass  fnlwgt     education  educational-num  marital-status  \
# 0       25          3  226802          11th                7               4
# 1       38          3   89814       HS-grad                9               2
# 2       28          1  336951    Assoc-acdm               12               2
# 3       44          3  160323  Some-college               10               2
# 4       18          2  103497  Some-college               10               4
# ...    ...        ...     ...           ...              ...             ...
# 48837   27          3  257302    Assoc-acdm               12               2
# 48838   40          3  154374       HS-grad                9               2
# 48839   58          3  151910       HS-grad                9               6
# 48840   22          3  201490       HS-grad                9               4
# 48841   52          4  287927       HS-grad                9               2
#
# ...

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Recreate x and y after label encoding
x = dataset.drop('income', axis=1)
y = dataset['income'].values.reshape(-1, 1)

# Drop rows with NaN values before scaling and splitting
dataset_cleaned_nan = dataset.dropna()
x = dataset_cleaned_nan.drop('income', axis=1)
y = dataset_cleaned_nan['income'].values.reshape(-1, 1)

# Drop the 'education' column as it contains string values
x = x.drop('education', axis=1)

x = scaler.fit_transform(x)

# %%
print(x)
# Out:
# [[-0.99217141 -0.03602351  0.35966949 ... -0.21790728 -0.03700178
#    0.23790282]
#  [-0.03984689 -0.03602351 -0.94106533 ... -0.21790728  0.76958223
#    0.23790282]
#  [-0.77240421 -1.78601815  1.40556139 ... -0.21790728 -0.03700178
#    0.23790282]
#  ...
#  [ 1.42526775 -0.03602351 -0.35144851 ... -0.21790728 -0.03700178
#    0.23790282]
#  [-1.21193861 -0.03602351  0.11932581 ... -0.21790728 -1.6501698
#    0.23790282]
#  [ 0.98573336  0.83897382  0.94006643 ... -0.21790728 -0.03700178
#    0.23790282]]

# %% [markdown]
# # Training And Testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 1)

# %%
x_train
# Out:
# array([[-0.18635836, -0.03602351,  5.1620518 , ..., -0.21790728,
#         -0.03700178,  0.23790282],
#        [-0.03984689, -0.03602351, -1.27337997, ..., -0.21790728,
#         -0.03700178,  0.23790282],
#        [ 0.3996875 , -0.03602351, -0.85891246, ..., -0.21790728,
#         -0.44029379,  0.23790282],
#        ...,
#        [ 0.69271043, -0.03602351,  0.13913289, ..., -0.21790728,
#         -0.03700178,  0.23790282],
#        [-0.33286982, -0.03602351,  0.98839723, ..., -0.21790728,
#         -0.03700178,  0.23790282],
#        [ 1.20550055,  1.71397114, -1.28524903, ..., -0.21790728,
#         -0.84358579,  0.23790282]])

# %% [markdown]
# # KNN (K-Nearest Neighbors)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train, y_train)
predict = classifier.predict(x_test)  #prediction
predict
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype=object)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print("Confusion Matrix:\n", confusion_matrix(y_test, predict))
print("\nClassification Report:\n", classification_report(y_test, predict))
print("Accuracy:", accuracy_score(y_test, predict))
# Out:
# Confusion Matrix:
#  [[6577  677]
#  [ 977 1364]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        <=50K       0.87      0.91      0.89      7254
#         >50K       0.67      0.58      0.62      2341
#
#     accuracy                           0.83      9595
#    macro avg       0.77      0.74      0.76      9595
# weighted avg       0.82      0.83      0.82      9595
#
# Accuracy: 0.8276185513288171

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
regressor = LogisticRegression()
regressor.fit(x_train, y_train)
predict1 = regressor.predict(x_test)
predict1
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype=object)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print("Confusion Matrix:\n", confusion_matrix(y_test, predict1))
print("\Classification Report:\n", classification_report(y_test, predict1))
print("Accuracy:", accuracy_score(y_test, predict1))
# Out:
# Confusion Matrix:
#  [[6839  415]
#  [1285 1056]]
# \Classification Report:
#                precision    recall  f1-score   support
#
#        <=50K       0.84      0.94      0.89      7254
#         >50K       0.72      0.45      0.55      2341
#
#     accuracy                           0.82      9595
#    macro avg       0.78      0.70      0.72      9595
# weighted avg       0.81      0.82      0.81      9595
#
# Accuracy: 0.8228243877019281

# %% [markdown]
# # Artificial Neural Networks (MLP - Multi-Layer Perceptron)

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(hidden_layer_sizes=(64,32), random_state = 1, max_iter = 300)
clf.fit(x_train, y_train)
predict2 = clf.predict(x_test)
predict2
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1124: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype='<U5')

# %%
from sklearn.metrics import accuracy_score
print("Accuracy:", accuracy_score(y_test, predict2))
# Out:
# Accuracy: 0.8486711829077644

# %% [markdown]
# # Support Vector Machine(SVM)

# %%
from sklearn.svm import SVC
svm_model = SVC(kernel='rbf', C=1, gamma='scale')  # Try kernel='linear' too
svm_model.fit(x_train, y_train)
predict3 = svm_model.predict(x_test)
predict3
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype=object)

# %%
print("Accuracy:", accuracy_score(y_test, predict3))
print("Confusion Matrix:\n", confusion_matrix(y_test, predict3))
print("Classification Report:\n", classification_report(y_test, predict3))
# Out:
# Accuracy: 0.8446065659197499
# Confusion Matrix:
#  [[6863  391]
#  [1100 1241]]
# Classification Report:
#                precision    recall  f1-score   support
#
#        <=50K       0.86      0.95      0.90      7254
#         >50K       0.76      0.53      0.62      2341
#
#     accuracy                           0.84      9595
#    macro avg       0.81      0.74      0.76      9595
# weighted avg       0.84      0.84      0.83      9595

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators = 100, random_state = 1)
rf_classifier.fit(x_train, y_train)
predict4 = rf_classifier.predict(x_test)
predict4
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype=object)

# %%
print("Accuracy:", accuracy_score(y_test, predict4))
print("Confusion Matrix:\n", confusion_matrix(y_test, predict4))
print("Classification Report:\n", classification_report(y_test, predict4))
# Out:
# Accuracy: 0.8581552892131319
# Confusion Matrix:
#  [[6800  454]
#  [ 907 1434]]
# Classification Report:
#                precision    recall  f1-score   support
#
#        <=50K       0.88      0.94      0.91      7254
#         >50K       0.76      0.61      0.68      2341
#
#     accuracy                           0.86      9595
#    macro avg       0.82      0.77      0.79      9595
# weighted avg       0.85      0.86      0.85      9595

# %% [markdown]
# # Model Comparison

# %%
import matplotlib.pyplot as plt
models = ['Logistic Regression', 'KNN', 'SVM', 'Random Forest', 'ANN']
accuracies = [82.28, 82.76, 84.46, 85.82, 84.87]
plt.bar(models, accuracies, color='skyblue')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Model Comparison')
plt.show()

# %% [markdown]
# # Selecting The Best Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import joblib

# %%
#Training,Testing And Spliting The Model

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)


models = {
    LogisticRegression(): 'Logistic Regression',
    RandomForestClassifier(): 'Random Forest',
    SVC(): 'SVM',
    KNeighborsClassifier(): 'KNN',
    MLPClassifier(): 'ANN'
}

results = {}


#Train And Evaluate


for model, name in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    results[name] = accuracy
    print(f"{name}: {accuracy:.4f}")

#Get Best Model

best_model_name = max(results, key=results.get)
best_model_object = [model_obj for model_obj, name in models.items() if name == best_model_name][0]
print(f"The best model is: {best_model_name} with accuracy: {results[best_model_name]:.4f}")


#Save The Best Model

joblib.dump(best_model_object, 'best_model.pkl')
print("Saved best model as best_model.pkl")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Logistic Regression: 0.8228
# Random Forest: 0.8588
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVM: 0.8446
# ...

# %%
# !pip install -q streamlit pyngrok

# %%
# Redefine x and y from the cleaned dataset
x = dataset.drop('income', axis=1)
y = dataset['income'].values.reshape(-1, 1)

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 1)

# %%
from sklearn.preprocessing import LabelEncoder
import joblib
from sklearn.model_selection import train_test_split
import pandas as pd


# Assuming X_train['education'], X_train['occupation'] used for training


occupation_encoder = LabelEncoder()
occupation_encoder.fit(X_train['occupation'])
joblib.dump(occupation_encoder, "occupation_encoder.pkl")

education_encoder = LabelEncoder()
education_encoder.fit(X_train['education'])
joblib.dump(education_encoder, "education_encoder.pkl")
# Out:
# ['education_encoder.pkl']

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import joblib
import numpy as np

# Load model and encoders
model = joblib.load("best_model.pkl")


# Recreate the LabelEncoders with the same classes used in training
education_encoder = joblib.load("education_encoder.pkl")
occupation_encoder = joblib.load("occupation_encoder.pkl")

# Streamlit UI
st.set_page_config(page_title="Employee Salary Predictor", layout="centered")
st.title("💼 Employee Salary Prediction App")
st.markdown("Predict whether an employee earns more than ₹50K based on input features")



# Inputs
age = st.slider("Age", 18, 65, 30)
education = st.selectbox("Education Level", education_encoder.classes_)
# ✅ Show original job roles in the dropdown (not numbers!)
occupation_options = list(occupation_encoder.classes_)
selected_occupation = st.selectbox("Job Role", occupation_options)
occupation = st.selectbox("Job Role",
                          ["Tech-support",  "Other", "Craft-repair",
                           "Other-service", "Sales","Exec-managerial", "Prof-specialty", "Handlers-cleaners",
                           "Adm-clerical", "Farming-fishing", "Transport-moving", "Priv-house-serv",
                           "Machine-op-inspct","Protective-serv", "Armed-Forces"])

# Encode selected role back to number
occ_encoded = occupation_encoder.transform([selected_occupation])[0]

hours = st.slider("Hours Worked Per Week", 1, 80, 40)
experience = st.slider("Years of Experience", 0, 40, 5)

# Encode categorical fields
edu_encoded = education_encoder.transform([education])[0]


# Prepare input as DataFrame
input_df = pd.DataFrame({
    'age': [age],
    'education': [edu_encoded],
    'occupation': [occ_encoded],
    'hours-per-week': [hours],
    'experiance': [experience],
    # Add other missing features here
    'feature6': [0],
    'feature7': [0],
    'feature8': [0],
    'feature9': [0],
    'feature10': [0],
    'feature11': [0],
    'feature12': [0]
})

# Prediction
if st.button("Predict Salary Class"):
    prediction = model.predict(input_df)[0]
    result = "≥ ₹50K" if prediction == 1 else "≤ ₹50K"
    st.success(f"🧾 Predicted Salary Class: **{result}**")
# Out:
# Overwriting app.py

# %%
# !nohup streamlit run app.py --server.port 8501 --server.enableCORS false &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# !ngrok authtoken 307ymKf94r7yqoiz6CIbKl5EsSl_2c7md99M7yrSSmR9K7xx6
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import os
import threading
def run_streamlit():

  os.system('streamlit run app.py --server.port 8501')

thread = threading.Thread(target = run_streamlit)
thread.start()

# %%
# !ngrok http 8501
# Out:
# ERROR:  authentication failed: Your account is limited to 1 simultaneous ngrok agent sessions.
# ERROR:  You can run multiple simultaneous tunnels from a single agent session by defining the tunnels in your agent configuration file and starting them with the command `ngrok start --all`.
# ERROR:  Read more about the agent configuration file: https://ngrok.com/docs/secure-tunnels/ngrok-agent/reference/config
# ERROR:  You can view your current agent sessions in the dashboard:
# ERROR:  https://dashboard.ngrok.com/agents
# ERROR:
# ERROR:  ERR_NGROK_108
# ERROR:  https://ngrok.com/docs/errors/err_ngrok_108
# ERROR:

# %%
from pyngrok import ngrok

# Kill previous tunnels if any
ngrok.kill()

# Create new tunnel
public_url = ngrok.connect(8501)
print("🌐 Streamlit App URL:", public_url)
# Out:
# 🌐 Streamlit App URL: NgrokTunnel: "https://942217097c56.ngrok-free.app" -> "http://localhost:8501"
